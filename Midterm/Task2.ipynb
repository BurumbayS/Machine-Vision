# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as pltimg

img = pltimg.imread('panda.jpg',0)

fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(img)
plt.subplot(222)
plt.hist(img.ravel(),256,[0,256]); plt.show()
